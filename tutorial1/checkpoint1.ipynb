# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for completion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>).
#
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
data_frame = pd.read_csv('../data/states_edu.csv')
data_frame
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
data_frame.rename({
    'GRADES_PK_G':'NUM_ENROLL_PREK',
    'GRADES_KG_G':'NUM_ENROLL_KINDER',
    'GRADES_4_G':'NUM_ENROLL_4',
    'GRADES_8_G':'NUM_ENROLL_8',
    'GRADES_12_G':'NUM_ENROLL_12',
    'GRADES_1_8_G':'NUM_ENROLL_PRIMARY',
    'GRADES_9_12_G':'NUM_ENROLL_HS',
    'GRADES_ALL_G':'NUM_ENROLL_ALL',
    'ENROLL':'NUM_ENROLL_ALL_EST'
},
axis=1, inplace=True)
data_frame.head()

data_frame["AVG_MATH_4_SCORE"].isna().sum()
data_frame.dropna(subset=['AVG_MATH_4_SCORE'], inplace=True)
data_frame.dropna(subset=['AVG_MATH_4_SCORE'], inplace=True)

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen one of Grade 4 Reading, Grade 4 Math, or Grade 8 Math to focus on: *Grade 4 Math*

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
data_frame["YEAR"].nunique()
# Out:
# 33

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average across all years in the test you chose?

# %%
state_avg = data_frame.groupby("STATE")["AVG_MATH_4_SCORE"].mean()
mich_v_ohio = state_avg.loc[["MICHIGAN", "OHIO"]]
mich_v_ohio.plot.bar(title="Average 4th Grade Math Score")
# Out:
# <Axes: title={'center': 'Average 4th Grade Math Score'}, xlabel='STATE'>

# %% [markdown]
# Find the average for your chosen test across all states in 2019

# %%
year_2019 = data_frame[data_frame["YEAR"] == 2019]
year_avg = year_2019["AVG_MATH_4_SCORE"].mean()
print(year_avg)
# Out:
# 239.9433962264151

# %% [markdown]
# For each state, find a maximum value for your chosen test score

# %%
state_score = data_frame.groupby("STATE")
state_score["AVG_MATH_4_SCORE"].max()
# Out:
# STATE
# ALABAMA                 233.0
# ALASKA                  237.0
# ARIZONA                 240.0
# ARKANSAS                240.0
# CALIFORNIA              235.0
# COLORADO                247.0
# CONNECTICUT             245.0
# DELAWARE                243.0
# DISTRICT_OF_COLUMBIA    235.0
# DODEA                   250.0
# FLORIDA                 246.0
# GEORGIA                 240.0
# HAWAII                  243.0
# IDAHO                   242.0
# ILLINOIS                239.0
# INDIANA                 249.0
# IOWA                    246.0
# KANSAS                  248.0
# KENTUCKY                242.0
# LOUISIANA               234.0
# MAINE                   246.0
# MARYLAND                247.0
# MASSACHUSETTS           253.0
# MICHIGAN                238.0
# MINNESOTA               253.0
# MISSISSIPPI             241.0
# MISSOURI                241.0
# MONTANA                 244.0
# NATIONAL                242.0
# NEBRASKA                246.0
# NEVADA                  237.0
# ...

# %% [markdown]
# *Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %%
data_frame["READING_MATH_DIFF"] = data_frame["AVG_MATH_4_SCORE"]-data_frame["AVG_READING_4_SCORE"]
data_frame.reset_index()
# Out:
#       index         PRIMARY_KEY          STATE  YEAR  NUM_ENROLL_ALL_EST  \
# 0         0        1992_ALABAMA        ALABAMA  1992                 NaN
# 1         1         1992_ALASKA         ALASKA  1992                 NaN
# 2         2        1992_ARIZONA        ARIZONA  1992                 NaN
# 3         3       1992_ARKANSAS       ARKANSAS  1992                 NaN
# 4         4     1992_CALIFORNIA     CALIFORNIA  1992                 NaN
# ...     ...                 ...            ...   ...                 ...
# 1710   1710       2019_VIRGINIA       VIRGINIA  2019                 NaN
# 1711   1711     2019_WASHINGTON     WASHINGTON  2019                 NaN
# 1712   1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019                 NaN
# 1713   1713      2019_WISCONSIN      WISCONSIN  2019                 NaN
# 1714   1714        2019_WYOMING        WYOMING  2019                 NaN
#
#       TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  \
# ...

# %% [markdown]
# Feature engineering justification: **<I added a column that tracks the difference between the math score and the reading score, which would then give us an insight of how math is becoming increasingly valued compared to the reading scores.>**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %%
avg_reading_by_year = data_frame.groupby('YEAR')["AVG_READING_4_SCORE"].mean()
avg_math_by_year = data_frame.groupby('YEAR')["AVG_MATH_4_SCORE"].mean()

avg_reading_by_year.plot(label='Average Reading Score', color='red')
avg_math_by_year.plot(label='Average Math Score', color='blue')

plt.xlabel('Year')
plt.ylabel('Average Score')
plt.title('Average 4th Grade Reading and Math Scores by Year')
# Out:
# Text(0.5, 1.0, 'Average 4th Grade Reading and Math Scores by Year')

# %% [markdown]
# **Difference between the increase in the average math score and the average reading score over the years. Math Scores are generally higher than reading scores throughout the years**

# %% [markdown]
# **Visualization 2**

# %%
data_frame.plot.scatter(x='AVG_MATH_4_SCORE', y='AVG_MATH_8_SCORE', alpha=0.8)
# Out:
# <Axes: xlabel='AVG_MATH_4_SCORE', ylabel='AVG_MATH_8_SCORE'>

# %% [markdown]
# **Correlation between the average math score in 4th grade and the average math score in 8th grade. In general, a high average 4th grade math score correlates to a high average 8th grade math score.**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
# X =
X = data_frame[['NUM_ENROLL_4','AVG_MATH_4_SCORE']].dropna()
# y = 
y = data_frame.loc[X.index]['AVG_MATH_8_SCORE']
y.fillna(y.median(), inplace=True)

# %%
# X_train, X_test, y_train, y_test = train_test_split(
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
#      X, y, test_size=, random_state=42)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(model.intercept_)
print(model.coef_)
model.score(X_test, y_test)
# Out:
# 56.9052555134831
# [-4.28817607e-06  9.42715568e-01]

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %%
print(np.mean(model.predict(X_test)-y_test))
print(np.mean(np.abs(model.predict(X_test)-y_test)))
print(np.mean((model.predict(X_test)-y_test)**2)**0.5)
# Out:
# -0.007337512668732876
# 3.0698083160805067
# 3.9749249995114626

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
col_name = 'AVG_MATH_4_SCORE'

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

plt.legend(['True Training','Predicted Training'])
plt.xlabel(col_name)
plt.ylabel('Math 8 Score')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %%
# col_name = 'COLUMN NAME OF ONE PREDICTOR"

# f = plt.figure(figsize=(12,6))
# plt.scatter(X_test[col_name], y_test, color = "blue")
# plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

# plt.legend(['True testing','Predicted testing'])
# plt.xlabel(col_name)
# plt.ylabel('NAME OF THE PREDICTOR')
# plt.title("Model Behavior on Testing Set")
